# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from WindPy import w
import datetime
import empyrical
# %matplotlib inline

# %%
w.start()
# Out:
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2017 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.
# .ErrorCode=0
# .Data=[OK!]

# %%
today = datetime.datetime.today()

# %%
theme = pd.read_excel(u'../data/行业分类表.xlsx', sheet_name=u'中信二级行业')

# %%
theme
# Out:
#        金融地产     可选消费    必选医药     信息科技  其他经济敏感  其他经济不敏感
# 0        保险       白酒  其他医药医疗     IT服务    油田服务     金属制品
# 1        证券     白色家电    中药生产     电子设备    运输设备     电站设备
# 2   股份制与城商行      乘用车      零售      半导体    化学制品    输变电设备
# 3   房地产开发管理      小家电    生物医药       传媒    建筑施工  合成纤维及树脂
# 4      国有银行      商用车    品牌服饰    计算机软件    工程机械     航空航天
# 5     信托及其他  照明设备及其他    其他饮料    新能源设备      普钢       造纸
# 6       NaN  汽车销售及服务    化学制药    计算机硬件    航空机场     电信运营
# 7       NaN     黑色家电      食品     增值服务    石油化工     其他军工
# 8       NaN     其他轻工     NaN    其他元器件  煤炭开采洗选       综合
# 9       NaN     建筑装修     NaN    汽车零部件   发电及电网     兵器兵装
# 10      NaN       水泥     NaN     通用设备    航运港口       农业
# 11      NaN   景区和旅行社     NaN   其他专用设备    公路铁路       林业
# 12      NaN    酒店及餐饮     NaN   通信设备制造    纺织制造       渔业
# 13      NaN     其他建材     NaN     仪器仪表    石油开采    房地产服务
# 14      NaN      NaN     NaN     化学原料    工业金属       玻璃
# 15      NaN      NaN     NaN     稀有金属    其他钢铁   摩托车及其他
# 16      NaN      NaN     NaN  环保及公用事业      贸易       牧业
# 17      NaN      NaN     NaN      NaN    煤炭化工     公交物流
# 18      NaN      NaN     NaN      NaN     NaN     农用化工
# 19      NaN      NaN     NaN      NaN     NaN      贵金属

# %%
mv = pd.read_excel(u'../data/行业分类表.xlsx', sheet_name=u'行业市值')

# %%
mv[u'行业名称'] = [x.rstrip(u'\(中信\)').rstrip(u'Ⅱ') for x in mv[u'名称']]

# %%
mv = mv.set_index(u'行业名称')

# %%
mv
# Out:
#                   代码           名称       总市值（亿元）
# 行业名称
# 石油开采     CI005101.WI    石油开采Ⅱ(中信)  11084.441325
# 石油化工     CI005102.WI     石油化工(中信)  10818.979336
# 油田服务     CI005103.WI    油田服务Ⅱ(中信)   1850.441855
# 煤炭开采洗选   CI005104.WI   煤炭开采洗选(中信)   7439.204476
# 煤炭化工     CI005105.WI     煤炭化工(中信)    800.282170
# 贵金属      CI005106.WI      贵金属(中信)   2680.508889
# 工业金属     CI005107.WI     工业金属(中信)   5774.631166
# 稀有金属     CI005108.WI    稀有金属Ⅱ(中信)   4685.537761
# 发电及电网    CI005109.WI    发电及电网(中信)  15855.953803
# 环保及公用事业  CI005110.WI  环保及公用事业(中信)   6182.600846
# 普钢       CI005111.WI       普钢(中信)   5581.918790
# 其他钢铁     CI005112.WI     其他钢铁(中信)   1930.871153
# 农用化工     CI005113.WI     农用化工(中信)   3217.233824
# 合成纤维及树脂  CI005114.WI  合成纤维及树脂(中信)   1735.661555
# 化学原料     CI005115.WI     化学原料(中信)   6370.341045
# 化学制品     CI005116.WI     化学制品(中信)   8262.977875
# 建筑施工     CI005117.WI    建筑施工Ⅱ(中信)  12824.286954
# 建筑装修     CI005118.WI    建筑装修Ⅱ(中信)   1555.773356
# 水泥       CI005119.WI      水泥Ⅱ(中信)   4470.210926
# 玻璃       CI005120.WI      玻璃Ⅱ(中信)   1295.920054
# 其他建材     CI005121.WI     其他建材(中信)   2964.165818
# 造纸       CI005122.WI      造纸Ⅱ(中信)   1522.757188
# 其他轻工     CI005123.WI    其他轻工Ⅱ(中信)   5239.472893
# 工程机械     CI005124.WI    工程机械Ⅱ(中信)   2867.621154
# 其他专用设备   CI005125.WI   其他专用设备(中信)   7870.130894
# 通用设备     CI005126.WI     通用设备(中信)   5609.677170
# 运输设备     CI005127.WI     运输设备(中信)   4458.598853
# 仪器仪表     CI005128.WI    仪器仪表Ⅱ(中信)   1383.536808
# 金属制品     CI005129.WI    金属制品Ⅱ(中信)    738.390839
# 电站设备     CI005130.WI    电站设备Ⅱ(中信)   1844.668175
# ...              ...          ...           ...
# 其他饮料     CI005157.WI    其他饮料Ⅱ(中信)   2297.751735
# 食品       CI005158.WI       食品(中信)  11309.052339
# 农业       CI005159.WI       农业(中信)   1772.649424
# 牧业       CI005160.WI       牧业(中信)   7902.556975
# 林业       CI005161.WI       林业(中信)    351.108134
# 渔业       CI005162.WI       渔业(中信)    202.459663
# 国有银行     CI005163.WI    国有银行Ⅱ(中信)  66419.749290
# 股份制与城商行  CI005164.WI  股份制与城商行(中信)  38761.175107
# 证券       CI005165.WI      证券Ⅱ(中信)  27127.637853
# 保险       CI005166.WI      保险Ⅱ(中信)  34357.489146
# 信托及其他    CI005167.WI    信托及其他(中信)   4394.898515
# 房地产开发管理  CI005168.WI  房地产开发管理(中信)  22355.115173
# 房地产服务    CI005169.WI   房地产服务Ⅱ(中信)    228.400781
# 公路铁路     CI005170.WI     公路铁路(中信)   4243.725063
# 公交物流     CI005171.WI     公交物流(中信)   5101.677514
# 航运港口     CI005172.WI     航运港口(中信)   6766.436719
# 航空机场     CI005173.WI     航空机场(中信)   6217.732816
# 半导体      CI005174.WI     半导体Ⅱ(中信)   6605.971770
# 电信运营     CI005175.WI    电信运营Ⅱ(中信)   2094.280622
# 计算机硬件    CI005176.WI    计算机硬件(中信)   4883.756522
# 传媒       CI005177.WI      传媒Ⅱ(中信)  15574.725917
# 综合       CI005178.WI      综合Ⅱ(中信)   4061.282475
# 电子设备     CI005179.WI    电子设备Ⅱ(中信)  13847.155930
# 其他元器件    CI005180.WI   其他元器件Ⅱ(中信)  17712.319941
# 通信设备制造   CI005181.WI   通信设备制造(中信)  14040.838205
# 增值服务     CI005182.WI    增值服务Ⅱ(中信)    444.589376
# 计算机软件    CI005183.WI    计算机软件(中信)  13018.473683
# IT服务     CI005184.WI     IT服务(中信)   4734.325494
# 纺织制造     CI005185.WI     纺织制造(中信)   1651.026589
# 品牌服饰     CI005186.WI     品牌服饰(中信)   2362.549694
#
# [86 rows x 3 columns]

# %%
columns = [u'金融地产', u'可选消费', u'必选医药', u'信息科技']
returns = {}
for col in columns:
    print(col)
    sectors = theme[col].dropna().tolist()
    codes, weights = [], []
    for s in sectors:
#         print(s)
    #     print(mv.loc[s][u'代码'])
    #     print(mv.loc[s][u'总市值（亿元）'])
        codes.append(mv.loc[s][u'代码'])
        weights.append(mv.loc[s][u'总市值（亿元）'])
    weights = np.array(weights)
    weights /= weights.sum()
    data = w.wsd(codes, 'close', '2010-01-01', today, 'Period=M')
    df = pd.DataFrame(np.array(data.Data).T, index=data.Times, columns=codes)
    df = df.pct_change()
    returns[col] = df.mul(weights, axis=1).sum(axis=1)
# Out:
# 金融地产
# 可选消费
# 必选医药
# 信息科技

# %%
df = pd.DataFrame(returns)

# %%
rets = df.mul(np.array([0.3, 0.3, 0.15, 0.25])).sum(axis=1)

# %%
data = w.wsd('000906.SH, 881001.WI, 000001.SH', 'close', '2010-01-01', today, 'Period=M')

# %%
bench = pd.DataFrame(np.array(data.Data).T, index=data.Times, columns=data.Codes)

# %%
bench = bench.pct_change()

# %%
bench.head()
# Out:
#             000906.SH  881001.WI  000001.SH
# 2010-01-29        NaN        NaN        NaN
# 2010-02-26   0.032900   0.031000   0.020958
# 2010-03-31   0.021180   0.025550   0.018730
# 2010-04-30  -0.078994  -0.076927  -0.076708
# 2010-05-31  -0.090590  -0.083031  -0.097005

# %%
fig, ax = plt.subplots(figsize=(16, 9))

ax.plot((1 + rets).cumprod(), color='blue', label=u'行业组合')
ax.plot((1 + bench['000906.SH']).cumprod(), color='red', label=u'中证800')
ax.plot((1 + bench['881001.WI']).cumprod(), color='black', label=u'万得全A')
ax.plot((1 + bench['000001.SH']).cumprod(), color='orange', label=u'上证综指')

ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
vals = ax.get_yticks()
ax.set_yticklabels(['{:2.2f}'.format(x) for x in vals])
ax.legend(fontsize=15)

# %%
def metric(daily_ret):
    an_ret = empyrical.annual_return(daily_ret, period='monthly')
    sharpe = empyrical.sharpe_ratio(daily_ret, risk_free=0.015/365, period='monthly')
    vol = empyrical.annual_volatility(daily_ret, period='monthly')
    maxdraw = empyrical.max_drawdown(daily_ret)
    print('Annual return: %.2f%%'%(an_ret*100))
    print('Sharpe ratio: %.2f'%(sharpe))
    print('Annual volatility: %.2f%%'%(vol*100))
    print('Max drawdown: %.2f%%'%(maxdraw*100))

# %%
metric(rets)
# Out:
# Annual return: 10.23%
# Sharpe ratio: 0.53
# Annual volatility: 23.84%
# Max drawdown: -37.64%

# %%
(1 + df).cumprod().plot(figsize=(16, 9))
plt.legend(fontsize=15)
