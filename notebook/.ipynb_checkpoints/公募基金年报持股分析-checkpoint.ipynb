# %%
import pyodbc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from WindPy import w
# %matplotlib inline

# %%
w.start()
# Out:
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2017 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.
# .ErrorCode=0
# .Data=[OK!]

# %%
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=10.0.185.138;DATABASE=JYDB;UID=js_dev;PWD=js_dev')

# %%
stock = '002008'

# %%
query = 'SELECT t.SecuCode, t.SecuAbbr, s.SecuCode, s.SecuAbbr, fund.ReportDate, fund.SharesHolding \
        FROM MF_StockPortfolioDetail as fund, SecuMain as t, SecuMain as s \
        WHERE s.SecuCode = \'%s\' \
            AND fund.InnerCode = t.InnerCode \
            AND fund.StockInnerCode = s.InnerCode \
            ORDER BY fund.ReportDate DESC, fund.SharesHolding DESC'%(stock)

# %%
df = pd.read_sql_query(query, con=conn)

# %%
df = df.set_index('ReportDate')

# %%
df.head()
# Out:
#            SecuCode SecuAbbr SecuCode SecuAbbr  SharesHolding
# ReportDate
# 2017-12-31   004450     嘉实前沿   002008     大族激光     28099671.0
# 2017-12-31   340007     兴全责任   002008     大族激光     11392000.0
# 2017-12-31   050009     博时新兴   002008     大族激光      4999943.0
# 2017-12-31   202005     南方成份   002008     大族激光      4500003.0
# 2017-12-31   519018    汇添富均衡   002008     大族激光      4398966.0

# %%
holding = df.groupby(df.index).sum().resample('6M').last()

# %%
holding
# Out:
#             SharesHolding
# ReportDate
# 2004-06-30       109099.0
# 2004-12-31        80692.0
# 2005-06-30          450.0
# 2005-12-31      5920343.0
# 2006-06-30     15951065.0
# 2006-12-31     48297302.0
# 2007-06-30    111212903.0
# 2007-12-31    120701122.0
# 2008-06-30    218997652.0
# 2008-12-31    210003264.0
# 2009-06-30     95753205.0
# 2009-12-31     87083854.0
# 2010-06-30     96339361.0
# 2010-12-31    178019805.0
# 2011-06-30    289442976.0
# 2011-12-31     87865486.0
# 2012-06-30     54184083.0
# 2012-12-31    152599371.0
# 2013-06-30    118482447.0
# 2013-12-31    255621468.0
# 2014-06-30    351395262.0
# 2014-12-31     82280099.0
# 2015-06-30     53454320.0
# 2015-12-31     91456373.0
# 2016-06-30     91333062.0
# 2016-12-31    122077704.0
# 2017-06-30    204515158.0
# 2017-12-31    190290704.0

# %%
holding.plot(figsize=(16, 9))

# %%
start, end = holding.index[0].strftime('%Y-%m-%d'), holding.index[-1].strftime('%Y-%m-%d')
print '%s.SZ'%(stock), start, end
data = w.wsd('%s.SZ'%(stock), 'free_float_shares', start, end)
# Out:
# 002008.SZ 2004-06-30 2017-12-31

# %%
shares = pd.DataFrame(np.array(data.Data).T, index=data.Times, columns=['shares'])

# %%
shares.index = pd.to_datetime(shares.index)

# %%
shares = shares.resample('6M').last()

# %%
shares.plot(figsize=(16, 9))

# %%
pert = pd.DataFrame(holding.values / shares.values, index=holding.index, columns=['percent'])

# %%
pert['percent'].plot(figsize=(16, 9))
