# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
# %matplotlib inline

# %%
df = pd.read_excel(u'../data/全部A股上市公司所属行业.xlsx')

# %%
df.head()
# Out:
#    SecuCode SecuAbbr       TotalMV FirstIndustryName SecondIndustryName  \
# 0    601398     工商银行  2.052900e+08                银行               国有银行
# 1    601939     建设银行  1.785078e+08                银行               国有银行
# 2    601318     中国平安  1.536820e+08             非银行金融                 保险
# 3    600519     贵州茅台  1.409868e+08              食品饮料                 白酒
# 4    601288     农业银行  1.263439e+08                银行               国有银行
#
#   ThirdIndustryName
# 0              国有银行
# 1              国有银行
# 2                保险
# 3                白酒
# 4              国有银行

# %%
theme_df = pd.read_excel(u'../data/行业分类表.xlsx', sheet_name=u'中信二级行业')

# %%
theme_df
# Out:
#        金融地产     可选消费    必选医药     信息科技       其他
# 0        保险       白酒  其他医药医疗     IT服务     油田服务
# 1        证券     白色家电    中药生产     电子设备     运输设备
# 2   股份制与城商行      乘用车      零售      半导体     化学制品
# 3   房地产开发管理      小家电    生物医药       传媒     建筑施工
# 4      国有银行      商用车    品牌服饰    计算机软件     工程机械
# 5     信托及其他  照明设备及其他    其他饮料    新能源设备       普钢
# 6       NaN  汽车销售及服务      牧业    计算机硬件     农用化工
# 7       NaN     黑色家电    化学制药     增值服务     航空机场
# 8       NaN     其他轻工      食品    其他元器件     石油化工
# 9       NaN     建筑装修     NaN    汽车零部件   煤炭开采洗选
# 10      NaN       水泥     NaN     通用设备      贵金属
# 11      NaN   景区和旅行社     NaN   其他专用设备    发电及电网
# 12      NaN    酒店及餐饮     NaN   通信设备制造     航运港口
# 13      NaN     其他建材     NaN     仪器仪表     公路铁路
# 14      NaN      NaN     NaN     化学原料     纺织制造
# 15      NaN      NaN     NaN     稀有金属     石油开采
# 16      NaN      NaN     NaN  环保及公用事业     工业金属
# 17      NaN      NaN     NaN      NaN       贸易
# 18      NaN      NaN     NaN      NaN     其他钢铁
# 19      NaN      NaN     NaN      NaN     煤炭化工
# 20      NaN      NaN     NaN      NaN     金属制品
# 21      NaN      NaN     NaN      NaN     电站设备
# 22      NaN      NaN     NaN      NaN    输变电设备
# 23      NaN      NaN     NaN      NaN  合成纤维及树脂
# 24      NaN      NaN     NaN      NaN     航空航天
# 25      NaN      NaN     NaN      NaN       造纸
# 26      NaN      NaN     NaN      NaN     电信运营
# 27      NaN      NaN     NaN      NaN     其他军工
# 28      NaN      NaN     NaN      NaN       综合
# 29      NaN      NaN     NaN      NaN     兵器兵装
# 30      NaN      NaN     NaN      NaN     公交物流
# 31      NaN      NaN     NaN      NaN       农业
# 32      NaN      NaN     NaN      NaN       林业
# 33      NaN      NaN     NaN      NaN       渔业
# 34      NaN      NaN     NaN      NaN    房地产服务
# 35      NaN      NaN     NaN      NaN       玻璃
# 36      NaN      NaN     NaN      NaN   摩托车及其他

# %%
theme2ind = {}
for key in theme_df.columns:
    theme2ind[key] = [x for x in theme_df[key] if x is not np.nan]

# %%
ind2theme = {}
for key, value in theme2ind.items():
    for element in value:
        ind2theme[element] = key

# %%
df['Theme'] = [ind2theme[x] for x in df['SecondIndustryName']]

# %%
results = df.groupby('Theme')['TotalMV'].sum()

# %%
results = results.sort_values(ascending=False)

# %%
results
# Out:
# Theme
# 金融地产    1.870490e+09
# 其他      1.482109e+09
# 信息科技    1.285959e+09
# 必选医药    7.069044e+08
# 可选消费    6.446227e+08
# Name: TotalMV, dtype: float64

# %%
weight = results / results.sum()

# %%
weight
# Out:
# Theme
# 金融地产    0.312264
# 其他      0.247427
# 信息科技    0.214681
# 必选医药    0.118012
# 可选消费    0.107615
# Name: TotalMV, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(16, 16))

labels = weight.index.tolist()
sizes = weight.values
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'red']

ax.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, startangle=140, textprops={'fontsize': 20})
# Out:
# ([<matplotlib.patches.Wedge at 0x14d31f70>,
#   <matplotlib.patches.Wedge at 0x14d3e3f0>,
#   <matplotlib.patches.Wedge at 0x14d3e8b0>,
#   <matplotlib.patches.Wedge at 0x14d3ed90>,
#   <matplotlib.patches.Wedge at 0x14d4a290>],
#  [Text(-1.05628,-0.30703,'金融地产'),
#   Text(0.498569,-0.980525,'其他'),
#   Text(1.0328,0.378594,'信息科技'),
#   Text(0.190703,1.08334,'必选医药'),
#   Text(-0.56043,0.94653,'可选消费')],
#  [Text(-0.576154,-0.167471,'31.2%'),
#   Text(0.271947,-0.534832,'24.7%'),
#   Text(0.563343,0.206506,'21.5%'),
#   Text(0.10402,0.590914,'11.8%'),
#   Text(-0.305689,0.516289,'10.8%')])
